# %%
import numpy as np
# read inspired_SVT.txt
with open('experiment_rank5_2000_1000.txt', 'r') as f:
    inspired_SVT = f.read()

# %%
times = inspired_SVT.split("\n")

# %%
construction_time = 0
for i in times[:-1]:
    print(i)
    construction_time += float(i.split(":")[-1])
# Out:
# Data Construction Time: 0.9534730911254883
# Data Construction Time: 1.0730640888214111
# Data Construction Time: 1.033693790435791
# Data Construction Time: 1.0496439933776855
# Data Construction Time: 1.0996479988098145
# Data Construction Time: 1.1707048416137695
# Data Construction Time: 1.1581008434295654
# Data Construction Time: 1.0643701553344727
# Data Construction Time: 1.1343879699707031
# Data Construction Time: 1.1531047821044922
# Data Construction Time: 1.1622951030731201
# Data Construction Time: 1.087397813796997
# Data Construction Time: 1.181396245956421
# Data Construction Time: 1.2250490188598633
# Data Construction Time: 1.1685209274291992
# Data Construction Time: 1.0454330444335938
# Data Construction Time: 1.1250970363616943
# Data Construction Time: 1.1535861492156982
# Data Construction Time: 1.0719358921051025
# Data Construction Time: 1.0883209705352783
# Data Construction Time: 1.0608317852020264
# Data Construction Time: 1.0640630722045898
# ...

# %%
float(times[-1].split(":")[-1]) - construction_time
# Out:
# 4.88624906539917

# %%
times
# Out:
# ['Data Construction Time: 0.9534730911254883',
#  'Data Construction Time: 1.0730640888214111',
#  'Data Construction Time: 1.033693790435791',
#  'Data Construction Time: 1.0496439933776855',
#  'Data Construction Time: 1.0996479988098145',
#  'Data Construction Time: 1.1707048416137695',
#  'Data Construction Time: 1.1581008434295654',
#  'Data Construction Time: 1.0643701553344727',
#  'Data Construction Time: 1.1343879699707031',
#  'Data Construction Time: 1.1531047821044922',
#  'Data Construction Time: 1.1622951030731201',
#  'Data Construction Time: 1.087397813796997',
#  'Data Construction Time: 1.181396245956421',
#  'Data Construction Time: 1.2250490188598633',
#  'Data Construction Time: 1.1685209274291992',
#  'Data Construction Time: 1.0454330444335938',
#  'Data Construction Time: 1.1250970363616943',
#  'Data Construction Time: 1.1535861492156982',
#  'Data Construction Time: 1.0719358921051025',
#  'Data Construction Time: 1.0883209705352783',
# ...
